# %%
# !git clone -b test_bug https://github.com/ZesyC/F3M
# !pip install setproctitle
# Out:
# Cloning into 'F3M'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 59 (delta 11), reused 22 (delta 7), pack-reused 31 (from 1)
# Receiving objects: 100% (59/59), 76.64 MiB | 36.74 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# ...

# %%
# %cd /content/F3M
# !unzip -o Datasets/baby/image_feat.npy.zip -d Datasets/baby/
# Out:
# /content/F3M
# Archive:  Datasets/baby/image_feat.npy.zip
#   inflating: Datasets/baby/image_feat.npy

# %%
# !python Main.py \
  --data baby \
  --gpu 0 \
  --seed 421 \
  --lr 1e-3 \
  --batch 1024 \
  --tstBat 256 \
  --reg 1e-5 \
  --epoch 50 \
  --latdim 64 \
  --gnn_layer 1 \
  --topk 20 \
  --ssl_reg 1e-1 \
  --temp 0.5 \
  --tstEpoch 1 \
  --keepRate 1 \
  --dims '[1000]' \
  --d_emb_size 10 \
  --steps 5 \
  --sampling_steps 5 \
  --rebuild_k 3 \
  --e_loss 2.0 \
  --ris_lambda 0.5 \
  --ris_adj_lambda 0.2 \
  --trans 0 \
  --cl_method 0 \
  --flow_prior popularity \
  --cf_prior_mix 0.5 \
  --cf_prior_dropout 0.5 \
  --flow_time_scale 1.0
# Out:
# Traceback (most recent call last):
#   File "/content/F3M/Main.py", line 1, in <module>
#     import torch
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 441, in <module>
#     _load_global_deps()
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 392, in _load_global_deps
#     _preload_cuda_deps()
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 359, in _preload_cuda_deps
#     _preload_cuda_lib(lib_folder, lib_name)
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 324, in _preload_cuda_lib
#     ctypes.CDLL(lib_path)
#   File "/usr/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
